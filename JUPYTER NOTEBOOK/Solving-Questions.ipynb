# %% [markdown]
# 1. find square and cube of a numnber

# %%
n = 12 
s = 12**2
c = 12**3
# print("Square",s,"\ncube:",c,)
print (f"find square {s} and cube {c}")
# Out:
# find square 144 and cube 1728

# %% [markdown]
# 2. find total costs

# %%
notebook = 10 
pen = 20 
costOfNotebook = 100
costOfPen = 5
total = ((notebook * costOfNotebook)+(pen * costOfPen))
print(f"total cost is: {total}")
# Out:
# total cost is: 1100
