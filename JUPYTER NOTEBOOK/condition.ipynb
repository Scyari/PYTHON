# %% [markdown]
# 1. PASS OR FAIL AVERAGE

# %%
phy = eval (input("Enter Number:"))
chem = eval (input("Enter Number:"))
math = eval (input("Enter Number:"))
average = (phy + chem + math) / 3
if phy >=80:
    print("Grade: B, Pass")
else:
    print("Grade: D, Fail")
if chem >=80:
    print("Grade: B, Pass")
else:
    print("Grade: D, Fail")
if math >=80:
    print("Grade: B, Pass")
else:
    print("Grade: D, Fail")
if average >=80:
    print("Grade: A, Pass")
else:
    print("Grade: D, Fail")
# Out:
# Grade: D, Fail
# Grade: B, Pass
# Grade: B, Pass
# Grade: D, Fail

# %% [markdown]
# 2. Maximum 2 Numbers

# %%
a = eval (input("Enter Number:"))
b = eval (input("Enter Number:"))
if a > b:
    print("a")
if a < b:
    print("b")
# Out:
# b

# %% [markdown]
# 3. OTP CHECK

# %%
a = eval (input("Enter Number:"))
if a == 222444:
    print("Authenticated")
else:
    print("UnAuthenticated")
# Out:
# UnAuthenticated

# %% [markdown]
# 4. ATM WITH-DRAWL SYSTEM

# %%
Balance = 2000
CorrectPin = 2026
EnteredPin = eval(input("Enter Pin:"))

if CorrectPin == EnteredPin:                                #another Branch
    Withdraw = eval(input("Enter Withdrawl amount:"))       #asking for Withdraw

    if Withdraw <= 0:                                        #Think this like a tree (DSA) one Branch
      print ("Amount must be a positive number")

    elif Withdraw > Balance:
      print ("Insufficient Balance")

    elif (Balance - Withdraw) < 500:                    
      print ("Minimum Account Balance Must be 500")

    else:
      Balance -= Withdraw
      print ("WithDrawl Successful")
      print ("WithDrawl Amount", Withdraw)
      print ("Remaining Balance", Balance)

else:
     print ("Wrong Pin")                                   #another Branch



# Diagram be like -->

          #           PIN correct?
          #          /            \
          #       NO                YES
          #       |                  |
          #  Wrong PIN        Enter withdrawal
          #                         |
          #                  Amount <= 0?
          #                  /         \
          #                YES          NO
          #                |             |
          #             Invalid       Amount > Balance?
          #                             /        \
          #                           YES         NO
          #                           |            |
          #                     Insufficient    Balance < 500?
          #                                        /       \
          #                                      YES        NO
          #                                      |           |
          #                                   Reject      Withdraw
# Out:
# WithDrawl Successful
# WithDrawl Amount 300
# Remaining Balance 1700

# %% [markdown]
# 5. Employee Bonus System

# %%
Salary = 40000
Exp = eval(input("Enter Exp:"))
Rating = eval(input("Enter Rating:"))

if Exp >= 5 and Rating >= 4.5:
    Bonus = (Salary * 20)/ 100
    New_Salary = Bonus + Salary
    print (f"Now Salary Will be {New_Salary}\nExcellent")

elif Exp >= 3 and Rating >= 4:
    Bonus = (Salary * 10)/ 100
    New_Salary = Bonus + Salary
    print (f"Now Salary Will be {New_Salary}\nGood")

else:
     Bonus = (Salary * 5)/ 100
     New_Salary = Bonus + Salary
     print (f"Now Salary Will be {New_Salary}\nAverage")
# Out:
# Now Salary Will be 48000.0
# Excellent

# %% [markdown]
# 6. leap Year

# %%
year = eval(input("Enter year:"))
print (f"entered year: {year}")
if year % 400 == 0 and year % 4 == 0 and year % 100 != 0:
    print ("leap Year")
else :
     print ("not a leap Year")
# Out:
# entered year: 2004
# not a leap Year

# %% [markdown]
# 7. Student Result System

# %%
phy = eval (input("Enter Number:"))
chem = eval (input("Enter Number:"))
math = eval (input("Enter Number:"))
print ("Math marks:",math)
print ("Phy marks:",phy)
print ("Chem marks:",chem)

if math > 40 and phy > 40 and chem > 40:
    print ("Pass")
    avg = (phy * chem * math)/3

    if avg >= 90:
        print ("Grade O")
    elif avg >= 80:
        print ("Grade: E")
    elif avg >= 70:
        print ("Grade: A")
    elif avg >= 60:
        print ("Grade: B")

else:
    ("Fail")
# Out:
# Math marks: 56
# Phy marks: 60
# Chem marks: 69
# Pass
# Grade O
