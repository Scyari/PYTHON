# %% [markdown]
# 1. USER INPUT
# EVAL only works on int & float (DOESNT WORK ON STRING DATA)

# %%
a = eval(input ("enter value: "))   #eval getting data
b = eval (input ("enter value: "))
print ("value is:", a)
print ("type is:", type(a))    # type calls for (type of data) 
print ("value is:",b)
print ("type is:", type(b))    # type calls for (type of data)
# Out:
# value is: 10
# type is: <class 'int'>
# value is: 20.35
# type is: <class 'float'>
